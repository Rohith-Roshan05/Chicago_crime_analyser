# %%
#importing necessery libraries and reading the file
import pandas as pd
data=pd.read_excel('/content/Crime_Data.xlsx')
display(data)
# Out:
#               ID Case Number                Date                      Block  \
# 0        5741943    HN549294 2007-08-25 09:22:18         074XX N ROGERS AVE
# 1          25953    JE240540 2021-05-24 15:06:00        020XX N LARAMIE AVE
# 2          26038    JE279849 2021-06-26 09:24:00      062XX N MC CORMICK RD
# 3       13279676    JG507211 2023-11-09 07:30:00           019XX W BYRON ST
# 4       13274752    JG501049 2023-11-12 07:59:00  086XX S COTTAGE GROVE AVE
# ...          ...         ...                 ...                        ...
# 549994   1715153     G516233 2001-08-27 23:00:00       036XX S LAKE PARK AV
# 549995   1799889     G625392 2001-10-16 16:30:00         065XX S STEWART AV
# 549996   1769834     G583569 2001-09-29 05:35:00    031XX N CENTRAL PARK AV
# 549997   1788327     G610965 2001-09-12 09:05:00          065XX S CICERO AV
# 549998   1810693     G627247 2001-10-18 17:34:00       053XX W FERDINAND ST
#
#         IUCR         Primary Type  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 549999 entries, 0 to 549998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    549999 non-null  int64
#  1   Case Number           549999 non-null  object
#  2   Date                  549999 non-null  datetime64[ns]
#  3   Block                 549999 non-null  object
#  4   IUCR                  549999 non-null  object
#  5   Primary Type          549999 non-null  object
#  6   Description           549999 non-null  object
#  7   Location Description  548326 non-null  object
#  8   Arrest                549999 non-null  bool
#  9   Domestic              549999 non-null  bool
#  10  Beat                  549999 non-null  int64
#  11  District              549999 non-null  int64
#  12  Ward                  213674 non-null  float64
#  13  Community Area        215093 non-null  float64
# ...

# %%
data['Location Description'].fillna('Unknown',inplace=True)
# Out:
# <ipython-input-26-33826d3eefc8>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Location Description'].fillna('Unknown',inplace=True)

# %%
data.isnull().sum()
# Out:
# ID                           0
# Case Number                  0
# Date                         0
# Block                        0
# IUCR                         0
# Primary Type                 0
# Description                  0
# Location Description         0
# Arrest                       0
# Domestic                     0
# Beat                         0
# District                     0
# Ward                    336325
# Community Area          334906
# FBI Code                     0
# X Coordinate              6912
# Y Coordinate              6912
# Year                         0
# Updated On                   0
# Latitude                  6912
# Longitude                 6912
# Location                  6912
# dtype: int64

# %%
blockcoordinates=data.groupby('Block')[['Latitude','Longitude']].first()
data['Latitude']=data['Latitude'].fillna(data['Block'].map(blockcoordinates['Latitude']))
data['Longitude']=data['Longitude'].fillna(data['Block'].map(blockcoordinates['Longitude']))

# %%
data.drop(['Ward','Community Area'],axis=1,inplace=True)

# %%
#data.drop('Updated On',axis=1,inplace=True)

# %%
data.drop(['X Coordinate','Y Coordinate'],axis=1,inplace=True)

# %%
data.isnull().sum()
# Out:
# ID                         0
# Case Number                0
# Date                       0
# Block                      0
# IUCR                       0
# Primary Type               0
# Description                0
# Location Description       0
# Arrest                     0
# Domestic                   0
# Beat                       0
# District                   0
# FBI Code                   0
# Year                       0
# Updated On                 0
# Latitude                1477
# Longitude               1477
# Location                6912
# dtype: int64

# %%
data['Longitude']=data['Longitude'].fillna('Unknown')
data['Latitude']=data['Latitude'].fillna('Unknown')

# %%
data.isnull().sum()
# Out:
# ID                         0
# Case Number                0
# Date                       0
# Block                      0
# IUCR                       0
# Primary Type               0
# Description                0
# Location Description       0
# Arrest                     0
# Domestic                   0
# Beat                       0
# District                   0
# FBI Code                   0
# Year                       0
# Updated On                 0
# Latitude                   0
# Longitude                  0
# Location                6912
# dtype: int64

# %%
# Split the datetime64[ns] column into separate Date and Time columns
data['Case_Date'] = data['Date'].dt.date  # Extract only the date part
data['Case_Time'] = data['Date'].dt.time  # Extract only the time part

# Verify the result
print(data[['Date', 'Case_Date', 'Case_Time']].head())
# Out:
#                  Date   Case_Date Case_Time
# 0 2007-08-25 09:22:18  2007-08-25  09:22:18
# 1 2021-05-24 15:06:00  2021-05-24  15:06:00
# 2 2021-06-26 09:24:00  2021-06-26  09:24:00
# 3 2023-11-09 07:30:00  2023-11-09  07:30:00
# 4 2023-11-12 07:59:00  2023-11-12  07:59:00

# %%
data['Location'] = data.apply(
    lambda row: f"({row['Latitude']}, {row['Longitude']})" if not pd.isna(row['Latitude']) and not pd.isna(row['Longitude']) else None,
    axis=1
)
data.head()
# Out:
#          ID Case Number                Date                      Block IUCR  \
# 0   5741943    HN549294 2007-08-25 09:22:18         074XX N ROGERS AVE  560
# 1     25953    JE240540 2021-05-24 15:06:00        020XX N LARAMIE AVE  110
# 2     26038    JE279849 2021-06-26 09:24:00      062XX N MC CORMICK RD  110
# 3  13279676    JG507211 2023-11-09 07:30:00           019XX W BYRON ST  620
# 4  13274752    JG501049 2023-11-12 07:59:00  086XX S COTTAGE GROVE AVE  454
#
#   Primary Type                                        Description  \
# 0      ASSAULT                                             SIMPLE
# 1     HOMICIDE                                FIRST DEGREE MURDER
# 2     HOMICIDE                                FIRST DEGREE MURDER
# 3     BURGLARY                                     UNLAWFUL ENTRY
# 4      BATTERY  AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MIN...
#
#   Location Description  Arrest  Domestic  Beat  District FBI Code  Year  \
# ...

# %%
data['Update_Date'] = data['Updated On'].dt.date  # Extract only the date part
data['Update_Time'] = data['Updated On'].dt.time  # Extract only the time part

# Verify the result
print(data[['Updated On', 'Update_Date', 'Update_Time']].head())
# Out:
#            Updated On Update_Date Update_Time
# 0 2015-08-17 15:03:40  2015-08-17    15:03:40
# 1 2023-11-18 15:39:49  2023-11-18    15:39:49
# 2 2023-11-18 15:39:49  2023-11-18    15:39:49
# 3 2023-11-18 15:39:49  2023-11-18    15:39:49
# 4 2023-12-09 15:41:24  2023-12-09    15:41:24

# %%
data.isnull().sum()
# Out:
# ID                      0
# Case Number             0
# Date                    0
# Block                   0
# IUCR                    0
# Primary Type            0
# Description             0
# Location Description    0
# Arrest                  0
# Domestic                0
# Beat                    0
# District                0
# FBI Code                0
# Year                    0
# Updated On              0
# Latitude                0
# Longitude               0
# Location                0
# Case_Date               0
# Case_Time               0
# Update_Date             0
# Update_Time             0
# dtype: int64

# %%
data.head()
# Out:
#          ID Case Number                Date                      Block IUCR  \
# 0   5741943    HN549294 2007-08-25 09:22:18         074XX N ROGERS AVE  560
# 1     25953    JE240540 2021-05-24 15:06:00        020XX N LARAMIE AVE  110
# 2     26038    JE279849 2021-06-26 09:24:00      062XX N MC CORMICK RD  110
# 3  13279676    JG507211 2023-11-09 07:30:00           019XX W BYRON ST  620
# 4  13274752    JG501049 2023-11-12 07:59:00  086XX S COTTAGE GROVE AVE  454
#
#   Primary Type                                        Description  \
# 0      ASSAULT                                             SIMPLE
# 1     HOMICIDE                                FIRST DEGREE MURDER
# 2     HOMICIDE                                FIRST DEGREE MURDER
# 3     BURGLARY                                     UNLAWFUL ENTRY
# 4      BATTERY  AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MIN...
#
#   Location Description  Arrest  Domestic  ...  FBI Code  Year  \
# ...

# %%
data.shape
# Out:
# (549999, 22)

# %%
cleaned_data=data[['ID','Case Number','Case_Date','Case_Time','Year','Block','IUCR','Primary Type','Description','Location Description','Arrest',	'Domestic','Beat','District','FBI Code','Update_Date','Update_Time','Latitude','Longitude','Location']]

# %%
cleaned_data.head()
# Out:
#          ID Case Number   Case_Date Case_Time  Year  \
# 0   5741943    HN549294  2007-08-25  09:22:18  2007
# 1     25953    JE240540  2021-05-24  15:06:00  2021
# 2     26038    JE279849  2021-06-26  09:24:00  2021
# 3  13279676    JG507211  2023-11-09  07:30:00  2023
# 4  13274752    JG501049  2023-11-12  07:59:00  2023
#
#                        Block IUCR Primary Type  \
# 0         074XX N ROGERS AVE  560      ASSAULT
# 1        020XX N LARAMIE AVE  110     HOMICIDE
# 2      062XX N MC CORMICK RD  110     HOMICIDE
# 3           019XX W BYRON ST  620     BURGLARY
# 4  086XX S COTTAGE GROVE AVE  454      BATTERY
#
#                                          Description Location Description  \
# 0                                             SIMPLE                OTHER
# 1                                FIRST DEGREE MURDER               STREET
# 2                                FIRST DEGREE MURDER          PARKING LOT
# ...

# %%
cleaned_data.to_csv('crime_cleaned.csv',index=False)
